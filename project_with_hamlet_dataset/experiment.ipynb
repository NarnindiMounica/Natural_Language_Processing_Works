# %% [markdown]
# ### Next Word Prediction Using Hamlet Dataset

# %%
#importing libraries

# %%
#loading dataset

import nltk
nltk.download('gutenberg')

from nltk.corpus import gutenberg

# Load Hamlet text
hamlet_text = gutenberg.raw('shakespeare-hamlet.txt')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\mouni\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %%
#raw data is placed in text file

with open("hamlet.txt", 'w') as file_obj:
    file_obj.write(hamlet_text)
